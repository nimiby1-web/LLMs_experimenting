# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyBbwSpBnLOKhhBaNliInp6gZi0uc-jJTsc"

from google import genai
client = genai.Client()

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="what are the most popular cat breeds?"
)
print(response.text)
# Out:
# That's a great question, but it's important to start with a key distinction:
#
# **The vast majority of cats in homes are NOT purebred.**
#
# They are commonly referred to as **Domestic Shorthairs** or **Domestic Longhairs**. These are essentially mixed-breed cats, and they are by far the most common and beloved feline companions globally! They come in every imaginable color, pattern, and personality, and they are incredibly popular.
#
# However, if you're asking about recognized **purebred cat breeds**, some consistently rank high in popularity according to organizations like the Cat Fanciers' Association (CFA) or The International Cat Association (TICA). These rankings can shift slightly year to year, but here are some of the most popular:
#
# 1.  **Ragdoll:**
#     *   **Known for:** Striking blue eyes, semi-long, silky coats, and incredibly docile, floppy personalities. They are often described as dog-like in their affection and love to be held.
#
# 2.  **Maine Coon:**
# ...
